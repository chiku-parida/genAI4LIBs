# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science','no-latex'])
plt.rcParams.update({'figure.dpi': '300'})
fig, ax1 = plt.subplots()

from ase.db import connect
db = connect('/home/charles/batsupcap/analyis/gen_sample/gen_Structure_eval_final.db')

convex_hull = []
for row in db.select():
    #if row.frac_novel_unique_stable_structures == 1:
        #atoms = row.toatoms()
        #if not any(elem in elements_not_present for elem in atoms.get_chemical_symbols()):
            #if 'Li' in atoms.get_chemical_symbols():
    convex_hull.append(row.avg_energy_above_hull_per_atom)# * 1000)


plt.hist(convex_hull, bins=70, edgecolor='black')
plt.xlabel('Energy Above Hull (eV/atom)')
plt.ylabel('Frequency')
plt.axvline(x=0.1, color='red', linestyle='--')

above_100 = sum(1 for x in convex_hull if x > 0.1)
below_100 = sum(1 for x in convex_hull if x <= 0.1)
print(f'Above 0.1 eV/atom: {above_100}')
print(f'Below 0.1 eV/atom: {below_100}')


plt.text(0.7, 0.85, f'Below 0.1 eV/atom: {below_100}', color='blue', transform=plt.gca().transAxes)
plt.text(0.7, 0.9, f'Above 0.1 eV/atom: {above_100}', color='red', transform=plt.gca().transAxes)

plt.show()
# Out:
# Above 0.1 eV/atom: 5373
# Below 0.1 eV/atom: 27227

# %%
plt.hist(convex_hull, bins=70, edgecolor='black')
plt.xlabel('Energy Above Hull (eV/atom)')
plt.ylabel('Frequency')
plt.axvline(x=0.1, color='red', linestyle='--')

above_100 = sum(1 for x in convex_hull if x > 0.1)
below_100 = sum(1 for x in convex_hull if x <= 0.1)
print(f'Above 0.1 eV/atom: {above_100}')
print(f'Below 0.1 eV/atom: {below_100}')


plt.text(0.6, 0.90, f'Stable: {below_100}', color='blue', transform=plt.gca().transAxes)
plt.text(0.6, 0.80, f'Unstable: {above_100}', color='red', transform=plt.gca().transAxes)

#plt.text(1.50, 60, f'Above 100 meV/atom: {above_100}', color='red')
#plt.text(-2.00, 70, f'Below 100 meV/atom: {below_100}', color='red')
#plt.title('Histogram of Convex Hull Energies Gen-3')
plt.show()
# Out:
# Above 0.1 eV/atom: 5373
# Below 0.1 eV/atom: 27227

# %%
from ase.db import connect
db = connect('/home/charles/batsupcap/analyis/gen_sample/gen_Structure_eval_final.db')

convex_hull = []
for row in db.select():
    if row.frac_novel_unique_stable_structures == 1:
        #atoms = row.toatoms()
        #if not any(elem in elements_not_present for elem in atoms.get_chemical_symbols()):
            #if 'Li' in atoms.get_chemical_symbols():
        convex_hull.append(row.avg_energy_above_hull_per_atom)# * 1000)

# %%
plt.hist(convex_hull, bins=70, edgecolor='black')
plt.xlabel('Energy Above Hull (eV/atom)')
plt.ylabel('Frequency')
plt.axvline(x=0.1, color='red', linestyle='--')

above_100 = sum(1 for x in convex_hull if x > 0.1)
below_100 = sum(1 for x in convex_hull if x <= 0.1)
print(f'Above 0.1 eV/atom: {above_100}')
print(f'Below 0.1 eV/atom: {below_100}')


plt.text(0.1, 0.90, f'Stable: {below_100}', color='blue', transform=plt.gca().transAxes)
#plt.text(0.6, 0.80, f'Unstable: {above_100}', color='red', transform=plt.gca().transAxes)

#plt.text(1.50, 60, f'Above 100 meV/atom: {above_100}', color='red')
#plt.text(-2.00, 70, f'Below 100 meV/atom: {below_100}', color='red')
#plt.title('Histogram of Convex Hull Energies Gen-3')
plt.show()
# Out:
# Above 0.1 eV/atom: 0
# Below 0.1 eV/atom: 12550

# %%
elements_not_present = ['Cd','As', 'Sb', 'Rb', 'Cs', 'Fr', 'Ra', 'Ac', 'Rf', 'Ce', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Pr', 'Pm', 'Ta', 'Db', 'W', 'Sg', 'Tc', 'Re', 'Os', 'Ir', 'Hg', 'Tl', 'Po', 'At']

# %%
from ase.db import connect
db = connect('/home/charles/batsupcap/analyis/gen_sample/gen_Structure_eval_final.db')

convex_hull = []
for row in db.select():
    if row.frac_novel_unique_stable_structures == 1:
        atoms = row.toatoms()
        if not any(elem in elements_not_present for elem in atoms.get_chemical_symbols()):
            if 'Li' in atoms.get_chemical_symbols():
                convex_hull.append(row.avg_energy_above_hull_per_atom)# * 1000)

# %%
plt.hist(convex_hull, bins=70, edgecolor='black')
plt.xlabel('Energy Above Hull (eV/atom)')
plt.ylabel('Frequency')
plt.axvline(x=0.1, color='red', linestyle='--')

above_100 = sum(1 for x in convex_hull if x > 0.1)
below_100 = sum(1 for x in convex_hull if x <= 0.1)
print(f'Above 0.1 eV/atom: {above_100}')
print(f'Below 0.1 eV/atom: {below_100}')


plt.text(0.1, 0.90, f'Stable: {below_100}', color='blue', transform=plt.gca().transAxes)
#plt.text(0.6, 0.80, f'Unstable: {above_100}', color='red', transform=plt.gca().transAxes)

#plt.text(1.50, 60, f'Above 100 meV/atom: {above_100}', color='red')
#plt.text(-2.00, 70, f'Below 100 meV/atom: {below_100}', color='red')
#plt.title('Histogram of Convex Hull Energies Gen-3')
plt.show()
# Out:
# Above 0.1 eV/atom: 0
# Below 0.1 eV/atom: 817

# %%
from ase.db import connect
db = connect('/home/charles/batsupcap/analyis/gen_sample/gen_Structure_eval_final.db')

convex_hull = []
for row in db.select():
    if row.frac_novel_unique_stable_structures == 1:
        atoms = row.toatoms()
        if not any(elem in elements_not_present for elem in atoms.get_chemical_symbols()):
            #if 'Li' in atoms.get_chemical_symbols():
            convex_hull.append(row.avg_energy_above_hull_per_atom)# * 1000)

# %%
plt.hist(convex_hull, bins=70, edgecolor='black')
plt.xlabel('Energy Above Hull (eV/atom)')
plt.ylabel('Frequency')
plt.axvline(x=0.1, color='red', linestyle='--')

above_100 = sum(1 for x in convex_hull if x > 0.1)
below_100 = sum(1 for x in convex_hull if x <= 0.1)
print(f'Above 0.1 eV/atom: {above_100}')
print(f'Below 0.1 eV/atom: {below_100}')


plt.text(0.1, 0.90, f'Stable: {below_100}', color='blue', transform=plt.gca().transAxes)
#plt.text(0.6, 0.80, f'Unstable: {above_100}', color='red', transform=plt.gca().transAxes)

#plt.text(1.50, 60, f'Above 100 meV/atom: {above_100}', color='red')
#plt.text(-2.00, 70, f'Below 100 meV/atom: {below_100}', color='red')
#plt.title('Histogram of Convex Hull Energies Gen-3')
plt.show()
# Out:
# Above 0.1 eV/atom: 0
# Below 0.1 eV/atom: 6221

# %%
from ase.db import connect
db = connect('/home/charles/batsupcap/analyis/structures_eval_dft.db')

convex_hull = []
for row in db.select():
    convex_hull.append(row.avg_energy_above_hull_per_atom)# * 1000)

# %%
plt.hist(convex_hull, bins=70, edgecolor='black')
plt.xlabel('Energy Above Hull (eV/atom)')
plt.ylabel('Frequency')
plt.axvline(x=0.1, color='red', linestyle='--')

above_100 = sum(1 for x in convex_hull if x > 0.1)
below_100 = sum(1 for x in convex_hull if x <= 0.1)
print(f'Above 0.1 eV/atom: {above_100}')
print(f'Below 0.1 eV/atom: {below_100}')


plt.text(0.6, 0.90, f'Stable: {below_100}', color='blue', transform=plt.gca().transAxes)
plt.text(0.6, 0.80, f'Unstable: {above_100}', color='red', transform=plt.gca().transAxes)

plt.xlim(-0.5, 4.0)

#plt.text(1.50, 60, f'Above 100 meV/atom: {above_100}', color='red')
#plt.text(-2.00, 70, f'Below 100 meV/atom: {below_100}', color='red')
#plt.title('Histogram of Convex Hull Energies Gen-3')
plt.show()
# Out:
# Above 0.1 eV/atom: 378
# Below 0.1 eV/atom: 425

# %%
425+378
# Out:
# 803

# %%
import pandas as pd
df_refs = pd.read_json("dataframe_pandas_eform_ehull.json.gz")
df_refs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153226 entries, 0 to 153225
# Data columns (total 60 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   material_id                      153226 non-null  object
#  1   chemsys                          153226 non-null  object
#  2   elements                         153226 non-null  object
#  3   nelements                        153226 non-null  int64
#  4   nsites                           153226 non-null  int64
#  5   composition                      153226 non-null  object
#  6   formula_pretty                   153226 non-null  object
#  7   crystal_system                   153226 non-null  object
#  8   space_group_number               153226 non-null  int64
#  9   space_group_symbol               153226 non-null  object
#  10  task_ids                         153226 non-null  object
# ...

# %%
elements_not_present = ['Cd','As', 'Sb', 'Rb', 'Cs', 'Fr', 'Ra', 'Ac', 'Rf', 'Ce', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Pr', 'Pm', 'Ta', 'Db', 'W', 'Sg', 'Tc', 'Re', 'Os', 'Ir', 'Hg', 'Tl', 'Po', 'At']

# %%
from ase.formula import Formula

# Filter entries containing 'Li' and excluding elements in elements_not_present
filtered_entries = df_refs[
    df_refs['elements'].apply(lambda elems: 'Li' in elems and not any(elem in elements_not_present for elem in elems))
]

# Extract energy_above_hull values
energy_above_hull_values = filtered_entries['energy_above_hull'].tolist()
# Out:
# [0.0, 0.0, 0.013319646000000001, 0.046423169800000004, 0.0, 0.0068342118, 0.0019011826000000002, 0.0, 0.2323727434, 0.23690857340000002, 0.0083821051, 0.3523755975, 0.2802606364, 0.075781523, 0.16198917840000002, 0.3989024366, 0.1286592748, 0.0002888341, 0.020441723300000002, 0.0055779010000000006, 0.047419116000000004, 0.0, 0.0898115084, 0.0997606303, 0.1174760353, 0.0276370141, 0.1847141347, 0.1199704597, 0.0142595221, 0.0, 0.19410442320000001, 0.139479345, 0.136310715, 0.0, 1.4161994117, 0.1530891598, 0.18222500060000002, 0.1279858848, 0.25115057700000004, 0.0769428627, 0.1034142913, 0.08841460770000001, 0.1808852641, 1.3741986737, 0.13614492820000001, 0.1525823843, 0.1444604317, 0.15431543690000002, 0.1381368117, 0.16537399730000002, 0.1486768403, 0.0734559703, 0.1158481185, 0.0548675668, 0.0, 0.1422360456, 0.2165834163, 0.158793492, 0.2179079506, 0.213826492, 0.2186211434, 0.1476209614, 0.1082080086, 0.1263084868, 0.0, 0.0144057427, 0.1878848497, 0.1955808783, 0.1267303226, 0.19
# ...

# %%
filtered_energy_values = [value for value in energy_above_hull_values if value <= 0.1]
print(filtered_energy_values)
# Out:
# [0.0, 0.0, 0.013319646000000001, 0.046423169800000004, 0.0, 0.0068342118, 0.0019011826000000002, 0.0, 0.0083821051, 0.075781523, 0.0002888341, 0.020441723300000002, 0.0055779010000000006, 0.047419116000000004, 0.0, 0.0898115084, 0.0997606303, 0.0276370141, 0.0142595221, 0.0, 0.0, 0.0769428627, 0.08841460770000001, 0.0734559703, 0.0548675668, 0.0, 0.0, 0.0144057427, 0.0772218771, 0.09296430200000001, 0.0, 0.0, 0.0176572127, 0.011304397, 0.060913670100000004, 0.0021803773, 0.0085040138, 0.0101808275, 0.0445591636, 0.0279763867, 0.0, 0.0116843317, 0.0066500278000000005, 0.0225376737, 0.0, 0.0886988672, 0.0895840053, 0.0935585491, 0.0454575471, 0.047385398, 0.0352152949, 0.047180593400000005, 0.0, 0.0225218682, 0.0, 0.0, 0.0012317103000000001, 0.024140333, 0.0, 0.0061587939, 0.0, 0.0514504078, 0.0155769354, 0.0084659518, 0.0318579006, 0.037716404, 0.0189270021, 0.0017212523, 0.0056718035, 0.0, 0.000136159, 0.0, 0.0, 0.0, 0.0088473773, 0.0, 0.0835595236, 0.00206884, 0.0, 0.0, 0.0, 0.0, 0.
# ...

# %%
from ase.db import connect
db = connect('/home/charles/batsupcap/analyis/gen_sample/gen_Structure_eval_final.db')

convex_hull = []
for row in db.select():
    if row.frac_novel_unique_stable_structures == 1:
        atoms = row.toatoms()
        if not any(elem in elements_not_present for elem in atoms.get_chemical_symbols()):
            if 'Li' in atoms.get_chemical_symbols():
                convex_hull.append(row.avg_energy_above_hull_per_atom)# * 1000)

# %%
print(len(convex_hull))
print(len(filtered_energy_values))
# Out:
# 817
# 15142

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import seaborn as sns
plt.style.use(['science','no-latex'])
plt.rcParams.update({'figure.dpi': '400'})
fig, ax1 = plt.subplots()

sns.kdeplot(filtered_energy_values, fill=True, color="blue", alpha=0.5, ax=ax1, label='Li-MP Data')
sns.kdeplot(convex_hull, fill=True, color="orange", alpha=0.5, ax=ax1, label='Li-Gen Structures')
ax1.set_xlabel('Energy Above Hull (eV/atom)')
ax1.set_ylabel('Density')
plt.legend(loc='upper left', fontsize='small', bbox_to_anchor=(0.0, 1))
#plt.xlim(-0.25, 0.15)
plt.axvline(x=0.0, color='red', linestyle='--')

plt.savefig('kernel_density_plot.png', dpi=400)
#ax1.set_title('Kernel Density Plot of Filtered Energy Values')

# %%
from collections import Counter
from ase.formula import Formula

# Collect the formula_as-queried
formulas = df_refs['formula_pretty'].tolist()
formulas_with_li = [formula for formula in formulas if 'Li' in formula]

# %%
print(len(formulas_with_li))
# Out:
# 21686

# %%
elements_not_present = ['Cd','As', 'Sb', 'Rb', 'Cs', 'Fr', 'Ra', 'Ac', 'Rf', 'Ce', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Pr', 'Pm', 'Ta', 'Db', 'W', 'Sg', 'Tc', 'Re', 'Os', 'Ir', 'Hg', 'Tl', 'Po', 'At']

filtered_formulas_with_li = [
    formula for formula in formulas_with_li
    if not any(elem in elements_not_present for elem in Formula(formula).count().keys())
]
print(len(filtered_formulas_with_li))
# Out:
# 19122

# %%
elements_not_present = ['Cd','As', 'Sb', 'Rb', 'Cs', 'Fr', 'Ra', 'Ac', 'Rf', 'Ce', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Pr', 'Pm', 'Ta', 'Db', 'W', 'Sg', 'Tc', 'Re', 'Os', 'Ir', 'Hg', 'Tl', 'Po', 'At']

# %%
list_of_elements = [
    'H','He','Li','Be','B','C','N','O','F','Ne','Na','Mg','Al','Si','P','S',
    'Cl','Ar','K','Ca','Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu','Zn','Ga',
    'Ge','As','Se','Br','Kr','Rb','Sr','Y','Zr','Nb','Mo','Tc','Ru','Rh','Pd',
    'Ag','Cd','In','Sn','Sb','Te','I','Xe','Cs','Ba','La','Ce','Pr','Nd','Pm',
    'Sm','Eu','Gd','Tb','Dy','Ho','Er','Tm','Yb','Lu','Hf','Ta','W','Re','Os',
    'Ir','Pt','Au','Hg','Tl','Pb','Bi','Po','At','Rn','Fr','Ra','Ac','Th','Pa',
    'U','Np','Pu','Am','Cm','Bk','Cf','Es','Fm','Md','No','Lr'
]
elements_not_present = ['Cd','As', 'Sb', 'Rb', 'Cs', 'Fr', 'Ra', 'Ac', 'Rf', 'Ce', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Pr', 'Pm', 'Ta', 'Db', 'W', 'Sg', 'Tc', 'Re', 'Os', 'Ir', 'Hg', 'Tl', 'Po', 'At']

present_elements = list(set(list_of_elements) - set(elements_not_present))

# %%
print(len(list_of_elements))
print(len(elements_not_present))
print(len(present_elements))
print(present_elements)
# Out:
# 103
# 38
# 68
# ['B', 'Pb', 'Ru', 'Ge', 'Mg', 'Se', 'Ag', 'Er', 'Li', 'Ga', 'Rn', 'F', 'Cu', 'Al', 'Yb', 'Zn', 'Rh', 'Lu', 'Mo', 'Ti', 'Nd', 'Si', 'Bi', 'H', 'Sc', 'Hf', 'Be', 'I', 'Te', 'Y', 'Kr', 'Au', 'Dy', 'Eu', 'Gd', 'K', 'P', 'V', 'Ar', 'Ho', 'Fe', 'Pd', 'Na', 'S', 'O', 'Co', 'Sn', 'Sr', 'N', 'Xe', 'C', 'Tm', 'Ne', 'La', 'Mn', 'In', 'Sm', 'Tb', 'He', 'Pt', 'Ni', 'Br', 'Cl', 'Zr', 'Cr', 'Ca', 'Ba', 'Nb']

# %%
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science','no-latex'])
plt.rcParams.update({'figure.dpi': '400'})
import numpy as np
import os
import pandas as pd
from math import pi

list_of_elements = [
    'H','He','Li','Be','B','C','N','O','F','Ne','Na','Mg','Al','Si','P','S',
    'Cl','Ar','K','Ca','Sc','Ti','V','Cr','Mn','Fe','Co','Ni','Cu','Zn','Ga',
    'Ge','As','Se','Br','Kr','Rb','Sr','Y','Zr','Nb','Mo','Tc','Ru','Rh','Pd',
    'Ag','Cd','In','Sn','Sb','Te','I','Xe','Cs','Ba','La','Ce','Pr','Nd','Pm',
    'Sm','Eu','Gd','Tb','Dy','Ho','Er','Tm','Yb','Lu','Hf','Ta','W','Re','Os',
    'Ir','Pt','Au','Hg','Tl','Pb','Bi','Po','At','Rn','Fr','Ra','Ac','Th','Pa',
    'U','Np','Pu','Am','Cm','Bk','Cf','Es','Fm','Md','No','Lr'
]
elements_not_present = ['Xe', 'Ar', 'He', 'Kr', 'Yb', 'Rn', 'Ne', 'Cd','As', 'Sb', 'Rb', 'Cs', 'Fr', 'Ra', 'Ac', 'Rf', 'Ce', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr', 'Pr', 'Pm', 'Ta', 'Db', 'W', 'Sg', 'Tc', 'Re', 'Os', 'Ir', 'Hg', 'Tl', 'Po', 'At']

present_elements = list(set(list_of_elements) - set(elements_not_present))


elements = [row['elements'] for index, row in df_refs.iterrows() if 'Li' in row['elements']]


data = {'Elements': elements}
#print(data)
mpdf = pd.DataFrame(data)


list_of_counts = [
    mpdf['Elements'].apply(lambda lst: element in lst).sum()
    for element in present_elements #list_of_elements
]

#print(list_of_counts)

# Normalize the counts
max_count = max(list_of_counts)
normalized_counts = [count / max_count for count in list_of_counts]
total_materials = len(mpdf)
#normalized_counts = [count / total_materials for count in list_of_counts]
# Sort the elements and their normalized counts
sorted_elements = [x for _, x in sorted(zip(normalized_counts, present_elements), reverse=True)]
sorted_counts = sorted(normalized_counts, reverse=True)

# Plot the sorted normalized counts
plt.style.use(['science', 'no-latex'])
plt.rcParams.update({'figure.dpi': '600','font.size': 16, 'axes.labelsize': 16, 'axes.titlesize': 16, 'xtick.labelsize': 12, 'ytick.labelsize': 12})

plt.figure(figsize=(15, 5))
plt.bar(sorted_elements, sorted_counts)
plt.xlim([-0.5, len(sorted_elements) - 0.5])
plt.xticks(rotation=90)
plt.ylabel('Normalized Number of Materials')
plt.xlabel('Element')
#plt.title('Sorted Normalized Element Distribution')
plt.tight_layout()
plt.show()
plt.savefig('sorted_normalized_element_distribution_MP.eps', dpi=600)

# %%
print(elements_in_li)

# %%
# Plot the sorted normalized counts
plt.style.use(['science', 'no-latex'])
plt.rcParams.update({'figure.dpi': '600','font.size': 28, 'axes.labelsize': 28, 'axes.titlesize': 16, 'xtick.labelsize': 24, 'ytick.labelsize': 24})

plt.figure(figsize=(24, 8))
plt.bar(sorted_elements, sorted_counts)
plt.xlim([-0.5, len(sorted_elements) - 0.5])
plt.xticks(rotation=90)
plt.ylabel('Normalized Number of Materials')
plt.xlabel('Element')
#plt.title('Sorted Normalized Element Distribution')
plt.tight_layout()
plt.savefig('sorted_normalized_element_distribution_MP.eps', dpi=600)
plt.show()

# %%
from ase.db import connect
db = connect('/home/charles/batsupcap/analyis/gen_sample/gen_Structure_eval_final.db')


elements_in_li = []
for row in db.select():
    atoms = row.toatoms()
    if not any(elem in elements_not_present for elem in atoms.get_chemical_symbols()):
        if 'Li' in atoms.get_chemical_symbols():
            elements_in_li.append(atoms.get_chemical_symbols())

# %%
print(len(elements_in_li))
print(db.count())
# Out:
# 1865
# 32600

# %%
data = {'Elements': elements_in_li}
#print(data)
mpdf = pd.DataFrame(data)


list_of_counts = [
    mpdf['Elements'].apply(lambda lst: element in lst).sum()
    for element in present_elements #list_of_elements
]

#print(list_of_counts)

# Normalize the counts
max_count = max(list_of_counts)
normalized_counts = [count / max_count for count in list_of_counts]
total_materials = len(mpdf)
#normalized_counts = [count / total_materials for count in list_of_counts]
# Sort the elements and their normalized counts
sorted_elements = [x for _, x in sorted(zip(normalized_counts, present_elements), reverse=True)]
sorted_counts = sorted(normalized_counts, reverse=True)


# Plot the sorted normalized counts
plt.style.use(['science', 'no-latex'])
plt.style.use(['science', 'no-latex'])
plt.rcParams.update({'figure.dpi': '600','font.size': 28, 'axes.labelsize': 28, 'axes.titlesize': 16, 'xtick.labelsize': 24, 'ytick.labelsize': 24})

plt.figure(figsize=(24, 8))
plt.bar(sorted_elements, sorted_counts)
plt.xlim([-0.5, len(sorted_elements) - 0.5])
plt.xticks(rotation=90)
plt.ylabel('Normalized Number of Materials')
plt.xlabel('Element')
#plt.title('Sorted Normalized Element Distribution GenData')
plt.tight_layout()
plt.savefig('sorted_normalized_element_distribution_gen.eps', dpi=600)
plt.show()
